# %% [markdown]
# <a href="https://colab.research.google.com/github/zhrvdt77/DSPS_ZVahdat/blob/main/HW2/movies_exploratory_Zahra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pylab as plt

# %% [markdown]
# This is a dataset of movies obtained from Kaggle. which is a platform that hosts data challenges (sometimes for prizes that can earn you a lot of money! the latest one is $50k!!)

# %%
movies = pd.read_csv("https://github.com/fedhere/FDSfE_FBianco/blob/main/data/movies_metadata_kaggle.csv.zip?raw=true", compression='zip')

# %%
# I am saving the initial size of the data set.
# If I decide to remove rows or columns (for example to deal with NaN values)
# I want to track how many I drop at every step
movies_start_size = movies.shape;
print("Shape: (rows, columns) =", movies_start_size);
# Out:
# Shape: (rows, columns) = (45454, 25)

# %%
movies.head();

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'earnings'],
#       dtype='object')

# %% [markdown]
# # Dealing with poor data encoding

# %% [markdown]
# The data contains a lot of metrics and descriptive features for 45454 movies. The features tho, are not always encoded in the way we would expect: for example, the "runtime" variable should be a number, but its encoded as an object (i.e. generally a string), see below

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45454 entries, 0 to 45453
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45454 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45454 non-null  float64
#  3   genres                 45454 non-null  object
#  4   homepage               7777 non-null   object
#  5   id                     45454 non-null  int64
#  6   imdb_id                45437 non-null  object
#  7   original_language      45443 non-null  object
#  8   original_title         45454 non-null  object
#  9   overview               44500 non-null  object
#  10  popularity             45451 non-null  float64
#  11  poster_path            45068 non-null  object
#  12  production_companies   45451 non-null  object
#  13  production_countries   45451 non-null  object
#  14  release_date           45368 non-null  object
#  15  revenue                45451 non-null  float64
#  16  runtime                45454 non-null  object
#  17  spoken_languages       45451 non-null  object
#  18  status                 45370 non-null  object
#  19  tagline                20406 non-null  object
#  20  title                  45451 non-null  object
#  21  video                  45451 non-null  object
#  22  vote_average           45451 non-null  float64
#  23  vote_count             45451 non-null  float64
#  24  earnings               10916 non-null  float64
# dtypes: bool(1), float64(6), int64(1), object(17)
# memory usage: 8.4+ MB

# %%
movies["runtime"][634:650]
# Out:
# 634     mean
# 635     mean
# 636    106.0
# 637    117.0
# 638    110.0
# 639     85.0
# 640    123.0
# 641     86.0
# 642    100.0
# 643    103.0
# 644     mean
# 645     93.0
# 646    100.0
# 647    100.0
# 648     92.0
# 649    115.0
# Name: runtime, dtype: object

# %% [markdown]
# Why is the numerical "runtime" variable encoded as a string? It happens if there are entries that are not numerical in a column that is otherwise numerical

# %% [markdown]
# I can convert a feature that contains strings of numbers to a numeric features, but if there are spurious entries I will get an error (_ValueError: Unable to parse string "mean" at position 634_)

# %%
movies["runtime"] = pd.to_numeric(movies["runtime"]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "mean"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-22dd7338bab3> in <cell line: 1>()
# ----> 1 movies["runtime"] = pd.to_numeric(movies["runtime"]);
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "mean" at position 634

# %% [markdown]
# To avoid that I have to "coerce" the conversion, which will make the non-numerical values converted to `NaN` or "Not a number".

# %%
movies["runtime"] = pd.to_numeric(movies["runtime"], errors='coerce')

# %% [markdown]
# Now lets look at the movie revenue per minute of film.

# %%
movies["revenue"] / movies["runtime"]
# Out:
# 0        4.611778e+06
# 1        2.526897e+06
# 2        0.000000e+00
# 3        6.413556e+05
# 4        7.224426e+05
#              ...
# 45449    0.000000e+00
# 45450    0.000000e+00
# 45451    0.000000e+00
# 45452    0.000000e+00
# 45453    0.000000e+00
# Length: 45454, dtype: float64

# %%
movies[[isinstance(movies["runtime"].values[i], float) for i in range(len(movies))]]
# Out:
#        adult                              belongs_to_collection      budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1      False                                                NaN  65000000.0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3      False                                                NaN  16000000.0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# ...      ...                                                ...         ...
# 45449  False                                                NaN         0.0
# 45450  False                                                NaN         0.0
# 45451  False                                                NaN         0.0
# 45452  False                                                NaN         0.0
# 45453  False                                                NaN         0.0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45449  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45450                      [{'id': 18, 'name': 'Drama'}]
# 45451  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45452                                                 []
# 45453                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45449  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45450                                   NaN  111109  tt2028550
# 45451                                   NaN   67758  tt0303758
# 45452                                   NaN  227506  tt0008536
# 45453                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45449                fa                      رگ خواب
# 45450                tl          Siglo ng Pagluluwal
# 45451                en                     Betrayal
# 45452                en          Satana likuyushchiy
# 45453                en                     Queerama
#
#                                                 overview  ...      revenue  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1      When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2      A family wedding reignites the ancient feud be...  ...          0.0
# 3      Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 4      Just when George Banks has recovered from his ...  ...   76578911.0
# ...                                                  ...  ...          ...
# 45449        Rising and falling between a man and woman.  ...          0.0
# 45450  An artist struggles to finish his work while a...  ...          0.0
# 45451  When one of her hits goes wrong, a professiona...  ...          0.0
# 45452  In a small town live two brothers, one a minis...  ...          0.0
# 45453  50 years after decriminalisation of homosexual...  ...          0.0
#
#       runtime                                   spoken_languages    status  \
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2       101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3       127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4       106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...       ...                                                ...       ...
# 45449    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45450   360.0                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45451    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45452    87.0                                                 []  Released
# 45453    75.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45449         Rising and falling between a man and woman
# 45450                                                NaN
# 45451                             A deadly game of wits.
# 45452                                                NaN
# 45453                                                NaN
#
#                              title  video vote_average vote_count   earnings
# 0                        Toy Story  False          7.7     5415.0  12.451801
# 1                          Jumanji  False          6.9     2413.0   4.043035
# 2                 Grumpier Old Men  False          6.5       92.0        NaN
# 3                Waiting to Exhale  False          6.1       34.0   5.090760
# 4      Father of the Bride Part II  False          5.7      173.0        inf
# ...                            ...    ...          ...        ...        ...
# 45449                       Subdue  False          4.0        1.0        NaN
# 45450          Century of Birthing  False          9.0        3.0        NaN
# 45451                     Betrayal  False          3.8        6.0        NaN
# 45452             Satan Triumphant  False          0.0        0.0        NaN
# 45453                     Queerama  False          0.0        0.0        NaN
#
# [45454 rows x 25 columns]

# %% [markdown]
# # Dealing with NaN and Infinities

# %% [markdown]
# now look at the description of the dataset. There are a few things to notice:
#
# - first, the "count" is not the same. But all columns have 45454 rows!! Yes, but not all are "valid" rows. Count tells you the number of non-NaN entires. After the conversion, for runtime that is 45194.
#
# - second, the variable "earnings" containes lots of NaN and also infinities. This is skewing all the statistics for this column! (note: I created that column, it was not originally in the dataset. Its revenue / budget and since budget has 0 values in it I get infinities in the fraction)

# %%
movies.describe()
# Out:
#              budget             id    popularity       revenue       runtime  \
# count  4.545400e+04   45454.000000  45451.000000  4.545100e+04  45194.000000
# mean   4.225399e+06  108348.389075      2.921765  1.121157e+07     94.133093
# std    1.742576e+07  112445.975875      6.005910  6.433842e+07     38.406223
# min    0.000000e+00       2.000000      0.000000  0.000000e+00      0.000000
# 25%    0.000000e+00   26447.500000      0.385945  0.000000e+00     85.000000
# 50%    0.000000e+00   60004.000000      1.127613  0.000000e+00     95.000000
# 75%    0.000000e+00  157304.000000      3.679334  0.000000e+00    107.000000
# max    3.800000e+08  469172.000000    547.488298  2.787965e+09   1256.000000
#
#        vote_average    vote_count      earnings
# count  45451.000000  45451.000000  1.091600e+04
# mean       5.618543    109.917538           inf
# std        1.924085    491.356914           NaN
# min        0.000000      0.000000  0.000000e+00
# 25%        5.000000      3.000000  0.000000e+00
# 50%        6.000000     10.000000  1.273533e+00
# 75%        6.800000     34.000000  7.267308e+00
# max       10.000000  14075.000000           inf

# %% [markdown]
# how many NaN do we have in each row?

# %%
movies.isna().sum(axis=0)
# Out:
# adult                        0
# belongs_to_collection    40963
# budget                       0
# genres                       0
# homepage                 37677
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   3
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                86
# revenue                      3
# runtime                    260
# spoken_languages             3
# status                      84
# tagline                  25048
# title                        3
# video                        3
# vote_average                 3
# vote_count                   3
# earnings                 34538
# dtype: int64

# %% [markdown]
# how many NaN _or infinities_ do we have in each row?

# %%
movies.isnull().sum(axis=0)
# Out:
# adult                        0
# belongs_to_collection    40963
# budget                       0
# genres                       0
# homepage                 37677
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   3
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                86
# revenue                      3
# runtime                    260
# spoken_languages             3
# status                      84
# tagline                  25048
# title                        3
# video                        3
# vote_average                 3
# vote_count                   3
# earnings                 34538
# dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45454 entries, 0 to 45453
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45454 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45454 non-null  float64
#  3   genres                 45454 non-null  object
#  4   homepage               7777 non-null   object
#  5   id                     45454 non-null  int64
#  6   imdb_id                45437 non-null  object
#  7   original_language      45443 non-null  object
#  8   original_title         45454 non-null  object
#  9   overview               44500 non-null  object
#  10  popularity             45451 non-null  float64
#  11  poster_path            45068 non-null  object
#  12  production_companies   45451 non-null  object
#  13  production_countries   45451 non-null  object
#  14  release_date           45368 non-null  object
#  15  revenue                45451 non-null  float64
#  16  runtime                45194 non-null  float64
#  17  spoken_languages       45451 non-null  object
#  18  status                 45370 non-null  object
#  19  tagline                20406 non-null  object
#  20  title                  45451 non-null  object
#  21  video                  45451 non-null  object
#  22  vote_average           45451 non-null  float64
#  23  vote_count             45451 non-null  float64
#  24  earnings               10916 non-null  float64
# dtypes: bool(1), float64(7), int64(1), object(16)
# memory usage: 8.4+ MB

# %% [markdown]
# # Using the missingno package to visualize the null and NaN content of our dataset

# %%
import missingno as msno
msno.matrix(movies);

# %% [markdown]
# Figure 1: This plot shows in white NaN cells and in gray valid cells for each feature as collumns. The "sparkline" plot on the right shows the number of valid entries per row. The lowest and highest number are marked explicitly: the row with more NaNs has only 8 valid entries, the most complete row(s) have all 25 values.

# %%
msno.matrix?

# %%
msno.heatmap?

# %%
#Presents a `seaborn` heatmap visualization of
#nullity correlation in the given DataFrame.
msno.heatmap(movies)
# Out:
# <Axes: >

# %% [markdown]
# Figure 2: This plot shows how correlated the presence of missing values is. Pairs of olumns for which all the same rows are missing are going to have a value of 1 in this plot. 0 if the rows that are missing in one column are all present in the other

# %%
movies.revenue
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45449            0.0
# 45450            0.0
# 45451            0.0
# 45452            0.0
# 45453            0.0
# Name: revenue, Length: 45454, dtype: float64

# %%
movies.budget
# Out:
# 0        30000000.0
# 1        65000000.0
# 2               0.0
# 3        16000000.0
# 4               0.0
#             ...
# 45449           0.0
# 45450           0.0
# 45451           0.0
# 45452           0.0
# 45453           0.0
# Name: budget, Length: 45454, dtype: float64

# %% [markdown]
# Number of movies for which popularity is not defined (NaN or inf)

# %%
# note that movies.popularity is (in most cases) the same as movies["popularity"]
movies.popularity.isnull().sum()
# Out:
# 3

# %%
np.round(.0103,4)
# Out:
# 0.0103

# %% [markdown]
# Fraction of movies for which "popularity" is not defined

# %%
movies.popularity.isnull().sum() / len(movies.popularity) # too many decimal digits!!
# Out:
# 6.600079200950411e-05

# %%
print("Fraction of movies with missing popularity score",
      np.round(movies.popularity.isnull().sum() / len(movies.popularity), 4))
# Out:
# Fraction of movies with missing popularity score 0.0001

# %% [markdown]
# # Filling in missing values with the mean value

# %%
movies["runtime"].fillna(movies["runtime"].mean(), inplace=True)

# %%
movies.popularity.fillna(movies.popularity.mean(), inplace=True)

# %%
msno.matrix(movies);

# %% [markdown]
# Figure 3 : same as before, but since I filled in missing values for runtime and popularity with the respective means now the columns are solid gray (all values available) and the row with fewest columns now has 10, not 8 (I guess it was missing both popularity and runtime!!)

# %% [markdown]
# Here is another way to convert a feature (column) made of strings containing (mostly) numbers to a floating point value feature

# %%
movies['budget'] = movies.budget.astype(float, errors='ignore')
movies['revenue'] = movies.revenue.astype(float, errors='ignore')

# %%
movies['budget'].isna().sum()
# Out:
# 0

# %%
plt.hist('budget')
plt.xticks([0])

# %% [markdown]
# # Lets plot some distribution of values. What is the right number of bins?
# There is a discussion on this in slack!

# %%
fig = plt.figure()
movies.hist('budget')
plt.xticks([0,1e8,2e8,3e8], labels=["0", "$100,000,000", "$200,000,000", "$300,000,000"]);
plt.ylabel("Number of movies");

# %% [markdown]
# Figure 4:  Too few bins. All I can tell is that most values are small (smaller than 30000000)

# %%
fig = plt.figure()
movies.hist('budget', bins=int(np.sqrt(3000000)));
plt.xticks([0,1e8,2e8,3e8], labels=["0", "$100,000,000", "$200,000,000", "$300,000,000"]);
plt.ylabel("Number of movies");
plt.xlim([0,300000000])
plt.ylim(0,250); # I had to cut the y range to see this

# %% [markdown]
# Figure 5:  Too many bins. Now I see spikes everywhere, I am plotting noise.

# %% [markdown]
# # there appear to be some movies (36810) made for less that 1,000 dollars... In faft for $0. I dont believe these are correct entries. I think this means that the person that curated the data set it to 0 where they should have set it to NaN

# %%
movies[movies.budget < 1e3];
# Out:
#        adult                              belongs_to_collection  budget  \
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...     0.0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...     0.0
# 7      False                                                NaN     0.0
# 11     False                                                NaN     0.0
# 12     False  {'id': 117693, 'name': 'Balto Collection', 'po...     0.0
# ...      ...                                                ...     ...
# 45449  False                                                NaN     0.0
# 45450  False                                                NaN     0.0
# 45451  False                                                NaN     0.0
# 45452  False                                                NaN     0.0
# 45453  False                                                NaN     0.0
#
#                                                   genres  \
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# 7      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11     [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# ...                                                  ...
# 45449  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45450                      [{'id': 18, 'name': 'Drama'}]
# 45451  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45452                                                 []
# 45453                                                 []
#
#                                    homepage      id    imdb_id  \
# 2                                       NaN   15602  tt0113228
# 4                                       NaN   11862  tt0113041
# 7                                       NaN   45325  tt0112302
# 11                                      NaN   12110  tt0112896
# 12                                      NaN   21032  tt0112453
# ...                                     ...     ...        ...
# 45449  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45450                                   NaN  111109  tt2028550
# 45451                                   NaN   67758  tt0303758
# 45452                                   NaN  227506  tt0008536
# 45453                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 2                    en             Grumpier Old Men
# 4                    en  Father of the Bride Part II
# 7                    en                 Tom and Huck
# 11                   en  Dracula: Dead and Loving It
# 12                   en                        Balto
# ...                 ...                          ...
# 45449                fa                      رگ خواب
# 45450                tl          Siglo ng Pagluluwal
# 45451                en                     Betrayal
# 45452                en          Satana likuyushchiy
# 45453                en                     Queerama
#
#                                                 overview  ...     revenue  \
# 2      A family wedding reignites the ancient feud be...  ...         0.0
# 4      Just when George Banks has recovered from his ...  ...  76578911.0
# 7      A mischievous young boy, Tom Sawyer, witnesses...  ...         0.0
# 11     When a lawyer shows up at the vampire's doorst...  ...         0.0
# 12     An outcast half-wolf risks his life to prevent...  ...  11348324.0
# ...                                                  ...  ...         ...
# 45449        Rising and falling between a man and woman.  ...         0.0
# 45450  An artist struggles to finish his work while a...  ...         0.0
# 45451  When one of her hits goes wrong, a professiona...  ...         0.0
# 45452  In a small town live two brothers, one a minis...  ...         0.0
# 45453  50 years after decriminalisation of homosexual...  ...         0.0
#
#       runtime                                   spoken_languages    status  \
# 2       101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4       106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7        97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 11       88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 12       78.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...       ...                                                ...       ...
# 45449    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45450   360.0                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45451    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45452    87.0                                                 []  Released
# 45453    75.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 2      Still Yelling. Still Fighting. Still Ready for...
# 4      Just When His World Is Back To Normal... He's ...
# 7                                 The Original Bad Boys.
# 11                                                   NaN
# 12                        Part Dog. Part Wolf. All Hero.
# ...                                                  ...
# 45449         Rising and falling between a man and woman
# 45450                                                NaN
# 45451                             A deadly game of wits.
# 45452                                                NaN
# 45453                                                NaN
#
#                              title  video vote_average vote_count earnings
# 2                 Grumpier Old Men  False          6.5       92.0      NaN
# 4      Father of the Bride Part II  False          5.7      173.0      inf
# 7                     Tom and Huck  False          5.4       45.0      NaN
# 11     Dracula: Dead and Loving It  False          5.7      210.0      NaN
# 12                           Balto  False          7.1      423.0      inf
# ...                            ...    ...          ...        ...      ...
# 45449                       Subdue  False          4.0        1.0      NaN
# 45450          Century of Birthing  False          9.0        3.0      NaN
# 45451                     Betrayal  False          3.8        6.0      NaN
# 45452             Satan Triumphant  False          0.0        0.0      NaN
# 45453                     Queerama  False          0.0        0.0      NaN
#
# [36810 rows x 25 columns]

# %% [markdown]
# This can cause problems. For example: what if I want to know what the net profit for a movie is (revenue / budget)

# %%
movies.revenue.astype(float) / movies.budget.astype(float)
# Out:
# 0        12.451801
# 1         4.043035
# 2              NaN
# 3         5.090760
# 4              inf
#            ...
# 45449          NaN
# 45450          NaN
# 45451          NaN
# 45452          NaN
# 45453          NaN
# Length: 45454, dtype: float64

# %%
movies.revenue.astype(float)
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45449            0.0
# 45450            0.0
# 45451            0.0
# 45452            0.0
# 45453            0.0
# Name: revenue, Length: 45454, dtype: float64

# %%
fig = plt.figure()
movies[movies.budget>0].hist('budget', bins=int(np.sqrt(len(movies[movies.budget>0]))));
plt.xticks([0,1e8,2e8,3e8], labels=["0", "$100,000,000", "$200,000,000", "$300,000,000"]);
plt.ylabel("Number of movies");
plt.xlim([0,300000000])
plt.ylim(0,3000); # I had to cut the y range to see this

# %%
fig = plt.figure()
movies[movies.budget > 0].hist('budget', bins=int(np.sqrt((movies.budget > 0).sum())));
plt.xticks([0,1e8,2e8,3e8], labels=["0", "$100,000,000", "$200,000,000", "$300,000,000"]);

# %% [markdown]
# Figure 6:  Much better number of bins! this was sqrt(size of sample).

# %% [markdown]
# # Remove from the dataset all movies with $0 budget

# %%
movies.shape
#(movies.budget == 0).sum()
# Out:
# (45454, 25)

# %%
(movies.budget == 0).sum()
# Out:
# 36565

# %%
(movies.budget == 0).sum() / movies.shape[0]
# Out:
# 0.8044396532758393

# %%
movies_start_size[0]
# Out:
# 45454

# %%
movies = movies[movies.budget > 0]
movies.shape
# Out:
# (8889, 25)

# %%
format((movies_start_size[0]-movies.shape[0])*100/movies_start_size[0])
# Out:
# '80.44396532758392'

# %%
print("{:.2f}%".format((movies_start_size[0]-movies.shape[0])*100/movies_start_size[0]))
# Out:
# 80.44%

# %%
print("new dataset size (rows, columns) =",  movies.shape)
print("I lost {:.2f}% of the data".format((movies_start_size[0] - movies.shape[0])
/ movies_start_size[0] * 100 )) #.2f here means use only 2 decimal digits
# Out:
# new dataset size (rows, columns) = (8889, 25)
# I lost 80.44% of the data

# %%
msno.matrix(movies);

# %% [markdown]
# Figure 6: now the least populated column has 20 entries!

# %%
movies.sort_values(by="earnings", ascending=True);

# %%
movies.sort_values(by="budget", ascending=True);

# %%
movies.sort_values(by="earnings", ascending=True);
movies.sort_values(by="earnings", ascending=False);

# %%
# remove entries with infinite earnings
movies.shape
# Out:
# (45454, 25)

# %%
movies.earnings.isin([np.inf]).sum()
# Out:
# 2027

# %%
movies[~movies.earnings.isin([np.inf])]
# Out:
#        adult                              belongs_to_collection      budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1      False                                                NaN  65000000.0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3      False                                                NaN  16000000.0
# 5      False                                                NaN  60000000.0
# ...      ...                                                ...         ...
# 45449  False                                                NaN         0.0
# 45450  False                                                NaN         0.0
# 45451  False                                                NaN         0.0
# 45452  False                                                NaN         0.0
# 45453  False                                                NaN         0.0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 5      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...                                                  ...
# 45449  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45450                      [{'id': 18, 'name': 'Drama'}]
# 45451  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45452                                                 []
# 45453                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 5                                       NaN     949  tt0113277
# ...                                     ...     ...        ...
# 45449  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45450                                   NaN  111109  tt2028550
# 45451                                   NaN   67758  tt0303758
# 45452                                   NaN  227506  tt0008536
# 45453                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 0                    en            Toy Story
# 1                    en              Jumanji
# 2                    en     Grumpier Old Men
# 3                    en    Waiting to Exhale
# 5                    en                 Heat
# ...                 ...                  ...
# 45449                fa              رگ خواب
# 45450                tl  Siglo ng Pagluluwal
# 45451                en             Betrayal
# 45452                en  Satana likuyushchiy
# 45453                en             Queerama
#
#                                                 overview  ...      revenue  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1      When siblings Judy and Peter discover an encha...  ...  262797249.0
# 2      A family wedding reignites the ancient feud be...  ...          0.0
# 3      Cheated on, mistreated and stepped on, the wom...  ...   81452156.0
# 5      Obsessive master thief, Neil McCauley leads a ...  ...  187436818.0
# ...                                                  ...  ...          ...
# 45449        Rising and falling between a man and woman.  ...          0.0
# 45450  An artist struggles to finish his work while a...  ...          0.0
# 45451  When one of her hits goes wrong, a professiona...  ...          0.0
# 45452  In a small town live two brothers, one a minis...  ...          0.0
# 45453  50 years after decriminalisation of homosexual...  ...          0.0
#
#       runtime                                   spoken_languages    status  \
# 0        81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2       101.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3       127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# ...       ...                                                ...       ...
# 45449    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45450   360.0                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45451    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45452    87.0                                                 []  Released
# 45453    75.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline                title  \
# 0                                                    NaN            Toy Story
# 1              Roll the dice and unleash the excitement!              Jumanji
# 2      Still Yelling. Still Fighting. Still Ready for...     Grumpier Old Men
# 3      Friends are the people who let you be yourself...    Waiting to Exhale
# 5                               A Los Angeles Crime Saga                 Heat
# ...                                                  ...                  ...
# 45449         Rising and falling between a man and woman               Subdue
# 45450                                                NaN  Century of Birthing
# 45451                             A deadly game of wits.             Betrayal
# 45452                                                NaN     Satan Triumphant
# 45453                                                NaN             Queerama
#
#        video vote_average vote_count   earnings
# 0      False          7.7     5415.0  12.451801
# 1      False          6.9     2413.0   4.043035
# 2      False          6.5       92.0        NaN
# 3      False          6.1       34.0   5.090760
# 5      False          7.7     1886.0   3.123947
# ...      ...          ...        ...        ...
# 45449  False          4.0        1.0        NaN
# 45450  False          9.0        3.0        NaN
# 45451  False          3.8        6.0        NaN
# 45452  False          0.0        0.0        NaN
# 45453  False          0.0        0.0        NaN
#
# [43427 rows x 25 columns]

# %%
movies = movies[~movies.earnings.isin([np.inf])]

# %%
movies.earnings.isin([np.inf]).sum()
# Out:
# 0

# %%
movies_start_size
# Out:
# (45454, 25)

# %%
movies.shape
# Out:
# (8889, 25)

# %%
print("we lost {:.2f}% of the movies".format((movies_start_size[0] - movies.shape[0]) /
                                          movies_start_size[0] * 100))
# Out:
# we lost 80.44% of the movies

# %%
movies.sort_values(by="earnings", ascending=True);

# %%
ax = movies.hist(column='runtime', bins = int(np.sqrt(len(movies))))
ax[0][0].set_xlabel("runtime (minutes)");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-7b4cf94fa339> in <cell line: 1>()
# ----> 1 ax = movies.hist(column='runtime', bins = int(np.sqrt(len(movies))))
#       2 ax[0][0].set_xlabel("runtime (minutes)");
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     229     """
#     230     plot_backend = _get_plot_backend(backend)
# --> 231     return plot_backend.hist_frame(
#     232         data,
#     233         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     497
#     498     if naxes == 0:
# --> 499         raise ValueError(
#     500             "hist method requires numerical or datetime columns, nothing to plot."
#     501         )
#
# ValueError: hist method requires numerical or datetime columns, nothing to plot.

# %%
ax = movies.hist(column='revenue', bins = int(np.sqrt(len(movies))))
ax[0][0].set_xlabel("revenue (Billions of $)");

# %% [markdown]
# #Consider only the low budget movies

# %%
nbins = int(np.sqrt(len(movies[movies.budget < 10])))
ax = movies[movies.budget < 10].hist(column='budget',
                    bins = nbins)
ax[0][0].set_xlabel("budget (Dollars? Thousands of $?)");

# %%
ax = movies[movies.revenue < 10].hist(column='revenue',bins = nbins)
ax[0][0].set_xlabel("revenue (Dollars?)");

# %%
print("There are {} movies with $0 revenue".format((movies["revenue"]==0).sum()))
# Out:
# There are 3508 movies with $0 revenue

# %%
#remove low budget moveis
movies = movies[movies.budget.astype(float) > 1e5]

# %%
print("we lost {:.2f}% of the movies".format((movies_start_size[0] - movies.shape[0]) /
                                          movies_start_size[0] * 100))
# Out:
# we lost 81.75% of the movies

# %%
movies_num
# Out:
#            budget      id  popularity      revenue  runtime  vote_average  \
# 0      30000000.0     862   21.946943  373554033.0     81.0           7.7
# 1      65000000.0    8844   17.015539  262797249.0    104.0           6.9
# 2             0.0   15602   11.712900          0.0    101.0           6.5
# 3      16000000.0   31357    3.859495   81452156.0    127.0           6.1
# 5      60000000.0     949   17.924927  187436818.0    170.0           7.7
# ...           ...     ...         ...          ...      ...           ...
# 45449         0.0  439050    0.072051          0.0     90.0           4.0
# 45450         0.0  111109    0.178241          0.0    360.0           9.0
# 45451         0.0   67758    0.903007          0.0     90.0           3.8
# 45452         0.0  227506    0.003503          0.0     87.0           0.0
# 45453         0.0  461257    0.163015          0.0     75.0           0.0
#
#        vote_count   earnings
# 0          5415.0  12.451801
# 1          2413.0   4.043035
# 2            92.0        NaN
# 3            34.0   5.090760
# 5          1886.0   3.123947
# ...           ...        ...
# 45449         1.0        NaN
# 45450         3.0        NaN
# 45451         6.0        NaN
# 45452         0.0        NaN
# 45453         0.0        NaN
#
# [43427 rows x 8 columns]

# %% [markdown]
# # Top 5 earning movies (now that we do not have nans or infinities in that column)

# %%
movies_num.sort_values(by="earnings")[:5]
# Out:
#           budget     id  popularity  revenue  runtime  vote_average  \
# 12651   222000.0  51929    0.151224      0.0    122.0           7.5
# 5512    226188.0  11868    8.355326      0.0     82.0           7.2
# 19301  8978040.0  93188    2.023954      0.0    139.0           6.7
# 19283  1552334.0  51190    0.368020      0.0    112.0           6.3
# 19278  6000000.0  20499    4.421468      0.0     92.0           4.1
#
#        vote_count  earnings
# 12651         7.0       0.0
# 5512        124.0       0.0
# 19301        24.0       0.0
# 19283         9.0       0.0
# 19278        14.0       0.0

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'earnings'],
#       dtype='object')

# %% [markdown]
# # Consider only numerical columns - create a separate DF for them

# %%
movies_num = movies.select_dtypes(include=np.number)
movies_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45454 entries, 0 to 45453
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   budget        45454 non-null  float64
#  1   id            45454 non-null  int64
#  2   popularity    45451 non-null  float64
#  3   revenue       45451 non-null  float64
#  4   vote_average  45451 non-null  float64
#  5   vote_count    45451 non-null  float64
#  6   earnings      10916 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 2.4 MB

# %%
movies_num.corr()
# Out:
#                 budget        id  popularity   revenue  vote_average  \
# budget        1.000000 -0.101672    0.449644  0.768774      0.073465
# id           -0.101672  1.000000   -0.083499 -0.071262     -0.167600
# popularity    0.449644 -0.083499    1.000000  0.506180      0.154378
# revenue       0.768774 -0.071262    0.506180  1.000000      0.083852
# vote_average  0.073465 -0.167600    0.154378  0.083852      1.000000
# vote_count    0.676639 -0.064897    0.559966  0.812021      0.123590
# earnings     -0.012566 -0.010124   -0.003940 -0.005509      0.013159
#
#               vote_count  earnings
# budget          0.676639 -0.012566
# id             -0.064897 -0.010124
# popularity      0.559966 -0.003940
# revenue         0.812021 -0.005509
# vote_average    0.123590  0.013159
# vote_count      1.000000 -0.003033
# earnings       -0.003033  1.000000

# %%
plt.imshow(movies_num.corr(), clim=(-1,1), cmap="RdBu")
plt.xticks(range(movies_num.shape[1]), movies_num.columns, rotation=90);
plt.yticks(range(movies_num.shape[1]), movies_num.columns);
plt.colorbar()

# %%
movies_num.columns
# Out:
# Index(['budget', 'id', 'popularity', 'revenue', 'runtime', 'vote_average',
#        'vote_count', 'earnings'],
#       dtype='object')

# %% [markdown]
# Figure X: the features are all postive correlated (id is weakly negative correlated with some values but id is an index and therefore it should not matter! unless it is a progressive number with the data of release, in which case.... we could argue its interesting to see that it goes done when popularity and revenue go up. BUT: the value is too small to assume it will be statistically consistent!!!)

# %% [markdown]
# # Pair plot
# A pair plot shows the linear correlation between features as a scatter plot (one feature on the x, one on the y, and the distribution of each feature on the diagonal line).
# The graphical package Seaborn has a nice function for it

# %%
import seaborn as sns
sns.pairplot(movies_num)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5da197b65bc9> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 sns.pairplot(movies_num)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2142     diag_kws.setdefault("legend", False)
#    2143     if diag_kind == "hist":
# -> 2144         grid.map_diag(histplot, **diag_kws)
#    2145     elif diag_kind == "kde":
#    2146         diag_kws.setdefault("fill", True)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1505             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1506             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1507             func(x=vector, **plot_kwargs)
#    1508             ax.legend_ = None
#    1509
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1430     if p.univariate:
#    1431
# -> 1432         p.plot_univariate_histogram(
#    1433             multiple=multiple,
#    1434             element=element,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     573
#     574                 plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 575                 artists = plot_func(
#     576                     hist["edges"],
#     577                     hist["heights"] - bottom,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2492             else:  # horizontal
#    2493                 r.sticky_edges.x.append(l)
# -> 2494             self.add_patch(r)
#    2495             patches.append(r)
#    2496
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2377         if p.get_clip_path() is None:
#    2378             p.set_clip_path(self.patch)
# -> 2379         self._update_patch_limits(p)
#    2380         self._children.append(p)
#    2381         p._remove_method = self._children.remove
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2419                 updatey = False
#    2420         trf_to_data = patch_trf - self.transData
# -> 2421         xys = trf_to_data.transform(vertices)
#    2422         self.update_datalim(xys, updatex=updatex, updatey=updatey)
#    2423
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/transforms.py in transform(self, values)
#    1488
#    1489         # Transform the values
# -> 1490         res = self.transform_affine(self.transform_non_affine(values))
#    1491
#    1492         # Convert the result back to the shape of the input values.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/transforms.py in transform_affine(self, points)
#    2413     def transform_affine(self, points):
#    2414         # docstring inherited
# -> 2415         return self.get_affine().transform(points)
#    2416
#    2417     def transform_non_affine(self, points):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/transforms.py in get_affine(self)
#    2440         else:
#    2441             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2442                                    self._a.get_affine().get_matrix()))
#    2443
#    2444     def inverted(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/transforms.py in get_matrix(self)
#    2599         if self._invalid:
#    2600             outl, outb, outw, outh = self._boxout.bounds
# -> 2601             if DEBUG and (outw == 0 or outh == 0):
#    2602                 raise ValueError("Transforming to a singular bounding box.")
#    2603             self._mtx = np.array([[outw,  0.0, outl],
#
# KeyboardInterrupt:

# %%
# Seaborn also has its own heatmap function
import seaborn as sns
corr = movies_num.corr()
sns.heatmap(corr,
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <Axes: >
