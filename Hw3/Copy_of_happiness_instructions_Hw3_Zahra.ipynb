# %% [markdown]
# <a href="https://colab.research.google.com/github/zhrvdt77/DSPS_ZVahdat/blob/main/Copy_of_happiness_instructions_Hw3_Zahra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW 3:
#
# Following the work we did together on the youtube videos and movies datasets, explore this dataset of "world happiness".
# This is a free form assignment: all the tasks have been performed in the _youtube videos_ or _movies_ data exploration we did in class (see class lectures and associated notebooks, also see Assignment 1 in HW 2).
#
# Find the datast happines.csv in
# https://github.com/fedhere/FDSfE_FBianco

# %% [markdown]
# On your own, perform the following tasks and report the results (with neat print statemnets as done in https://github.com/fedhere/FDSfE_FBianco/blob/main/HW2/movies_exploratory_instructions.ipynb, and remember that _all_ figures need axis labels and figure captions).
#
# 1. find the shape of the dataframe
# 2. show the top _10 rows_ and bottom _10 rows_ of the dataframe (_done in the videos and movies exploration_)
# 3. find statistical properties of the numerical columns of the dataframe (mean, standard deviation, quantiles etc)  (_done in the videos and movies exploration_)
# 4. inspect if the dataframe has missing values (_done in the movies exploration_). If it does have any decide how to deal with them: you can remove the rows or columns with missing values (with _drop_ or _dropna_ as we did in the movies assignment, but make sure you do not need them to answer the following questions before you drop them!), or replace them with some value that you thin is appropriate, for example with with _fillna_, see instructions on this function [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)). The choice of how to deal with missing values is yours, but you do have to end up with a dataframe with no missing values (make sure you show that the resulting dataframe has no missing values either with a printed output or with a plot).
# 5. find the happiest country.
# 6. is the happiest country also the top country in any of the following variables: [Economy (GDP per Capita),	Family	Health, (Life Expectancy),	Freedom	Trust (Government Corruption),Generosity	Dystopia Residual]
#
# 7. find the happiness score for a country of your choice, for example your country of origin, or any country you like. We did not do this exact task in either notebook _but_ to do that you can use a condition like `df["Happiness Score"] == "mycountry"` - this is similar to what you did to get the maximum value for a country: `df["Happiness Score"] == df["Happiness Score"].max()` and then use this statement as an index for the dataframe).
#
# 8. find the top 10 happiest coutries (using the `sort_values` function like we did in class for the videos analysis - _done in the videos and movies exploration_)
# 9. measure the correlation among (numerical) variables (_done in the videos and movies exploration_)
# 10. show a plot of the correlation of (numerical) variables (we did it in a couple of different ways in the youtube videos notebook) and describe it in a caption - what do you see? any noticeable correlations or anticorrelations? (_done in the videos and movies exploration_)
#
# THE LAST TWO TASKS ARE A BIT HARDER BECAUSE WE DID NOT DO ThEM TOGETHER IN CLASS SO THEY ARE GUIDED BELOW
#
# 11. aggregate the countries by region with `_group_by()` (_done in the videos and movies exploration_) and find the region with the highest "Generosity")
#
#
#
#
#
#
#
# REMEMBER:
# - for each plot make a caption that states "what" and "why" (see HW2 assignment 1) and make sure the plots have appropriate axis labels.
# - for every "finding" make sure the result is clear, for example by clearly extracting it in a print statement or by writing a text cell below the core that shows the result
# - save your notebook on Github in your FDSfE repository as HW1_happiness.ipynb

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp

# %%
happiness15 = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSfE_FBianco/main/data/happines.csv")

# %% [markdown]
# ...... do all the tasks through 1-10. You have done before in the previous homework and in class so you should be familiar with them!

# %%
print(" 1. The shape of thedatadrame is:",happiness15.shape)
# Out:
#  1. The shape of thedatadrame is: (160, 12)

# %% [markdown]
# 2. The top and bottom 10 rows are:

# %%
happiness15[0:10]
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
# 5                   1.29025  1.31826                   0.88911  0.64169
# 6                   1.32944  1.28017                   0.89284  0.61576
# 7                   1.33171  1.28907                   0.91087  0.65980
# 8                   1.25018  1.31967                   0.90837  0.63938
# 9                   1.33358  1.30923                   0.93156  0.65124
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 0                        0.41978     0.29678            2.51738  2015
# 1                        0.14145     0.43630            2.70201  2015
# 2                        0.48357     0.34139            2.49204  2015
# 3                        0.36503     0.34699            2.46531  2015
# 4                        0.32957     0.45811            2.45176  2015
# 5                        0.41372     0.23351            2.61955  2015
# 6                        0.31814     0.47610            2.46570  2015
# 7                        0.43844     0.36262            2.37119  2015
# 8                        0.42922     0.47501            2.26425  2015
# 9                        0.35637     0.43562            2.26646  2015

# %%
happiness15[-10:]
# Out:
#           Country                           Region  Happiness Score  \
# 150   Ivory Coast               Sub-Saharan Africa            3.655
# 151  Burkina Faso               Sub-Saharan Africa            3.587
# 152   Afghanistan                    Southern Asia            3.575
# 153        Rwanda               Sub-Saharan Africa            3.465
# 154         Benin               Sub-Saharan Africa            3.340
# 155         Syria  Middle East and Northern Africa            3.006
# 156       Burundi               Sub-Saharan Africa            2.905
# 157          Togo               Sub-Saharan Africa            2.839
# 158       Namibia                              NaN            4.639
# 159        Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 153         0.03464                   0.22208  0.77370
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
# 158             NaN                   0.87900      NaN
# 159             NaN                   0.30800      NaN
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 150                   0.15185  0.46866                        0.17922
# 151                   0.27125  0.39493                        0.12832
# 152                   0.30335  0.23414                        0.09719
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
# 158                   0.47700  0.40100                        0.05600
# 159                   0.42800  0.38200                        0.16700
#
#      Generosity  Dystopia Residual  year
# 150     0.20165            1.41723  2015
# 151     0.21747            1.46494  2015
# 152     0.36510            1.95210  2015
# 153     0.22628            0.67042  2015
# 154     0.18260            1.63328  2015
# 155     0.47179            0.32858  2015
# 156     0.19727            1.83302  2015
# 157     0.16681            1.56726  2015
# 158     0.07000                NaN  2019
# 159     0.26900                NaN  2019

# %% [markdown]
# 3. The statistical properties of the dataset:

# %%
happiness15.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       160.000000      158.000000                160.000000  158.000000
# mean          5.365756        0.047885                  0.842979    0.991046
# std           1.141280        0.017146                  0.402840    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.517750        0.037268                  0.539453    0.856823
# 50%           5.203000        0.043940                  0.901085    1.029510
# 75%           6.193250        0.052300                  1.155523    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                160.000000  160.000000                     160.000000
# mean                   0.628037    0.428151                       0.143023
# std                    0.246332    0.149803                       0.119492
# min                    0.000000    0.000000                       0.000000
# 25%                    0.437897    0.328630                       0.061067
# 50%                    0.695745    0.434635                       0.107220
# 75%                    0.809837    0.547057                       0.179565
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual         year
# count  160.000000         158.000000   160.000000
# mean     0.236448           2.098977  2015.050000
# std      0.126605           0.553550     0.445805
# min      0.000000           0.328580  2015.000000
# 25%      0.148800           1.759410  2015.000000
# 50%      0.216130           2.095415  2015.000000
# 75%      0.307547           2.462415  2015.000000
# max      0.795880           3.602140  2019.000000

# %%
happiness15.isnull().sum(axis=0)
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %% [markdown]
# 4. Inspect if the dataframe has missing values (done in the movies exploration). If it does have any decide how to deal with them.
#
# I find the nan values and subsitute them with median of the quantitive values. For qualitative values, I put "ohers".

# %%
happiness15.isna().sum(axis=0)
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %%
happiness15.isnull().sum(axis=0)
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno
msno.matrix(happiness15);

# %%
happiness15.Region.fillna("Other", inplace=True)

# %%
happiness15.isnull().sum(axis=0)
# Out:
# Country                          0
# Region                           0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# year                             0
# dtype: int64

# %%
happiness15["Standard Error"].median()
# Out:
# 0.04394

# %%
happiness15["Standard Error"].fillna(happiness15["Standard Error"].median(), inplace=True)

# %%
happiness15["Family"].median()
# Out:
# 1.02951

# %%
happiness15["Family"].fillna(happiness15["Family"].median(), inplace=True)

# %%
happiness15["Dystopia Residual"].median()
# Out:
# 2.095415

# %%
happiness15["Dystopia Residual"].fillna(happiness15["Dystopia Residual"].median(), inplace=True)

# %%
happiness15.isnull().sum(axis=0)
# Out:
# Country                          0
# Region                           0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# year                             0
# dtype: int64

# %% [markdown]
# 5. Find the happieset country?
# Switzerland

# %%
happiness15[happiness15["Happiness Score"]==happiness15["Happiness Score"].max()].Country
# Out:
# 0    Switzerland
# Name: Country, dtype: object

# %% [markdown]
# 6. Is the happiest country also the top country in any of the following variables: [Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom Trust (Government Corruption),Generosity, Dystopia Residual]?
# The answer is no.

# %%
happiness15[happiness15["Economy (GDP per Capita)"]==happiness15["Economy (GDP per Capita)"].max()].Country
# Out:
# 27    Qatar
# Name: Country, dtype: object

# %%
happiness15[happiness15["Family"]==happiness15["Family"].max()].Country
# Out:
# 1    Iceland
# Name: Country, dtype: object

# %%
happiness15[happiness15["Health (Life Expectancy)"]==happiness15["Health (Life Expectancy)"].max()].Country
# Out:
# 23    Singapore
# Name: Country, dtype: object

# %%
happiness15[happiness15["Freedom"]==happiness15["Freedom"].max()].Country
# Out:
# 3    Norway
# Name: Country, dtype: object

# %%
happiness15[happiness15["Trust (Government Corruption)"]==happiness15["Trust (Government Corruption)"].max()].Country
# Out:
# 153    Rwanda
# Name: Country, dtype: object

# %%
happiness15[happiness15["Generosity"]==happiness15["Generosity"].max()].Country
# Out:
# 128    Myanmar
# Name: Country, dtype: object

# %%
happiness15[happiness15["Dystopia Residual"]==happiness15["Dystopia Residual"].max()].Country
# Out:
# 13    Mexico
# Name: Country, dtype: object

# %% [markdown]
# 7. Find the happiness score for a country of your choice, for example your country of origin, or any country you like. We did not do this exact task in either notebook but to do that you can use a condition like df["Happiness Score"] == "mycountry" - this is similar to what you did to get the maximum value for a country: df["Happiness Score"] == df["Happiness Score"].max() and then use this statement as an index for the dataframe).

# %% [markdown]
# The happiness score of my country "Iran" is 4.686.

# %%
happiness15[happiness15["Country"]=="Iran"]["Happiness Score"]
# Out:
# 109    4.686
# Name: Happiness Score, dtype: float64

# %%
happiness15[happiness15["Country"]=="Switzerland"]["Happiness Score"]
# Out:
# 0    7.587
# Name: Happiness Score, dtype: float64

# %%
happiness15[happiness15["Happiness Score"]==happiness15["Happiness Score"].min()].Country
# Out:
# 157    Togo
# Name: Country, dtype: object

# %%
happiness15[happiness15["Country"]=="Togo"]["Happiness Score"]
# Out:
# 157    2.839
# Name: Happiness Score, dtype: float64

# %%
happiness15["Happiness Score"].mean()
# Out:
# 5.36575625

# %% [markdown]
# 8. Find the top 10 happiest coutries (using the sort_values function like we did in class for the videos analysis - done in the videos and movies exploration)

# %%
happiness15.sort_values(by="Happiness Score", ascending=False)[0:10]
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
# 5                   1.29025  1.31826                   0.88911  0.64169
# 6                   1.32944  1.28017                   0.89284  0.61576
# 7                   1.33171  1.28907                   0.91087  0.65980
# 8                   1.25018  1.31967                   0.90837  0.63938
# 9                   1.33358  1.30923                   0.93156  0.65124
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 0                        0.41978     0.29678            2.51738  2015
# 1                        0.14145     0.43630            2.70201  2015
# 2                        0.48357     0.34139            2.49204  2015
# 3                        0.36503     0.34699            2.46531  2015
# 4                        0.32957     0.45811            2.45176  2015
# 5                        0.41372     0.23351            2.61955  2015
# 6                        0.31814     0.47610            2.46570  2015
# 7                        0.43844     0.36262            2.37119  2015
# 8                        0.42922     0.47501            2.26425  2015
# 9                        0.35637     0.43562            2.26646  2015

# %% [markdown]
# 9. Measure the correlation among (numerical) variables (done in the videos and movies exploration)

# %%
happiness15.corr()
# Out:
# <ipython-input-26-d3251f92a443>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   happiness15.corr()
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.174642
# Standard Error                       -0.174642        1.000000
# Economy (GDP per Capita)              0.780130       -0.214553
# Family                                0.737011       -0.121081
# Health (Life Expectancy)              0.725936       -0.307085
# Freedom                               0.568437       -0.128965
# Trust (Government Corruption)         0.395285       -0.177176
# Generosity                            0.182865       -0.086368
# Dystopia Residual                     0.528906        0.083972
# year                                 -0.077951       -0.025795
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780130  0.737011
# Standard Error                                -0.214553 -0.121081
# Economy (GDP per Capita)                       1.000000  0.640487
# Family                                         0.640487  1.000000
# Health (Life Expectancy)                       0.815719  0.528010
# Freedom                                        0.370565  0.440846
# Trust (Government Corruption)                  0.303545  0.204737
# Generosity                                    -0.013182  0.086060
# Dystopia Residual                              0.039884  0.148087
# year                                          -0.069896  0.015837
#
#                                Health (Life Expectancy)   Freedom  \
# Happiness Score                                0.725936  0.568437
# Standard Error                                -0.307085 -0.128965
# Economy (GDP per Capita)                       0.815719  0.370565
# Family                                         0.528010  0.440846
# Health (Life Expectancy)                       1.000000  0.361440
# Freedom                                        0.361440  1.000000
# Trust (Government Corruption)                  0.248882  0.492886
# Generosity                                     0.111181  0.372662
# Dystopia Residual                              0.018975  0.062778
# year                                          -0.080426 -0.027613
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Score                                     0.395285    0.182865
# Standard Error                                     -0.177176   -0.086368
# Economy (GDP per Capita)                            0.303545   -0.013182
# Family                                              0.204737    0.086060
# Health (Life Expectancy)                            0.248882    0.111181
# Freedom                                             0.492886    0.372662
# Trust (Government Corruption)                       1.000000    0.280428
# Generosity                                          0.280428    1.000000
# Dystopia Residual                                  -0.033023   -0.100682
# year                                               -0.029774   -0.059681
#
#                                Dystopia Residual      year
# Happiness Score                         0.528906 -0.077951
# Standard Error                          0.083972 -0.025795
# Economy (GDP per Capita)                0.039884 -0.069896
# Family                                  0.148087  0.015837
# Health (Life Expectancy)                0.018975 -0.080426
# Freedom                                 0.062778 -0.027613
# Trust (Government Corruption)          -0.033023 -0.029774
# Generosity                             -0.100682 -0.059681
# Dystopia Residual                       1.000000 -0.000722
# year                                   -0.000722  1.000000

# %% [markdown]
# 10. Show a plot of the correlation of (numerical) variables (we did it in a couple of different ways in the youtube videos notebook) and describe it in a caption - what do you see? any noticeable correlations or anticorrelations? (done in the videos and movies exploration)

# %%
plt.imshow(happiness15.corr(), clim=(-1,1), cmap="RdBu")
plt.xticks(range(happiness15.shape[1]), happiness15.columns, rotation=90);
plt.yticks(range(happiness15.shape[1]), happiness15.columns);
plt.colorbar()
# Out:
# <ipython-input-27-ad46cb486bef>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.imshow(happiness15.corr(), clim=(-1,1), cmap="RdBu")

# %% [markdown]
# Figure X: Some of the features are postively correlated and some are negatively correlated. Happiness score is highly and positively correlated with the country and economy. Most of the other factors are uncorrelated (or slightly negatively) correlated with the regoin. Year and Dystopia residual don't show any correlations with other factors.

# %% [markdown]
# TASK 11

# %% [markdown]
# 11. Aggregate the countries by region with _group_by() (done in the videos and movies exploration) and find the region with the highest "Generosity")

# %% [markdown]
# the groupby method of a dataframe allows you to group rows based on having the same value for a specified column. It returns a `groupby object` which is not super helpful. But to that object you can apply methods, such as `mean()`, or `count()` to figure out what is the mean of the rows in that group, or how many objects are in each group (respetively `mean()` and `count()`, but there are many other methods!!).
#
# the syntax is
# `df.groupby("column name").mean()`
# and
# `df.groupby("column name").count()`
#
# for a dataframe called `df` and the column called "column name" you want to base the grouping on
#
# When you apply a method to the `groupby object` the return of that method is a dataframe, with the same columns as the original dataframe, but only one row per group and the values in each row-column cell is the value generated by applying the method to that group of rows and that column.
#
# Try and get the **mean "Generosity" per world region** (adapting the lines of code I gave you above), then sort the dataframe that results from this by "Generosity" and find the most ... generose region of the world.

# %%
happiness15.groupby("Region").count()
# Out:
#                                  Country  Happiness Score  Standard Error  \
# Region
# Australia and New Zealand              2                2               2
# Central and Eastern Europe            29               29              29
# Eastern Asia                           6                6               6
# Latin America and Caribbean           22               22              22
# Middle East and Northern Africa       20               20              20
# North America                          2                2               2
# Southeastern Asia                      9                9               9
# Southern Asia                          7                7               7
# Sub-Saharan Africa                    40               40              40
# Western Europe                        21               21              21
#
#                                  Economy (GDP per Capita)  Family  \
# Region
# Australia and New Zealand                               2       2
# Central and Eastern Europe                             29      29
# Eastern Asia                                            6       6
# Latin America and Caribbean                            22      22
# Middle East and Northern Africa                        20      20
# North America                                           2       2
# Southeastern Asia                                       9       9
# Southern Asia                                           7       7
# Sub-Saharan Africa                                     40      40
# Western Europe                                         21      21
#
#                                  Health (Life Expectancy)  Freedom  \
# Region
# Australia and New Zealand                               2        2
# Central and Eastern Europe                             29       29
# Eastern Asia                                            6        6
# Latin America and Caribbean                            22       22
# Middle East and Northern Africa                        20       20
# North America                                           2        2
# Southeastern Asia                                       9        9
# Southern Asia                                           7        7
# Sub-Saharan Africa                                     40       40
# Western Europe                                         21       21
#
#                                  Trust (Government Corruption)  Generosity  \
# Region
# Australia and New Zealand                                    2           2
# Central and Eastern Europe                                  29          29
# Eastern Asia                                                 6           6
# Latin America and Caribbean                                 22          22
# Middle East and Northern Africa                             20          20
# North America                                                2           2
# Southeastern Asia                                            9           9
# Southern Asia                                                7           7
# Sub-Saharan Africa                                          40          40
# Western Europe                                              21          21
#
#                                  Dystopia Residual  year
# Region
# Australia and New Zealand                        2     2
# Central and Eastern Europe                      29    29
# Eastern Asia                                     6     6
# Latin America and Caribbean                     22    22
# Middle East and Northern Africa                 20    20
# North America                                    2     2
# Southeastern Asia                                9     9
# Southern Asia                                    7     7
# Sub-Saharan Africa                              40    40
# Western Europe                                  21    21

# %%
happiness16=happiness15.groupby("Region").count()

# %%
happiness16.sort_values(by="Generosity", ascending=False)
# Out:
#                                  Country  Happiness Score  Standard Error  \
# Region
# Sub-Saharan Africa                    40               40              40
# Central and Eastern Europe            29               29              29
# Latin America and Caribbean           22               22              22
# Western Europe                        21               21              21
# Middle East and Northern Africa       20               20              20
# Southeastern Asia                      9                9               9
# Southern Asia                          7                7               7
# Eastern Asia                           6                6               6
# Australia and New Zealand              2                2               2
# North America                          2                2               2
#
#                                  Economy (GDP per Capita)  Family  \
# Region
# Sub-Saharan Africa                                     40      40
# Central and Eastern Europe                             29      29
# Latin America and Caribbean                            22      22
# Western Europe                                         21      21
# Middle East and Northern Africa                        20      20
# Southeastern Asia                                       9       9
# Southern Asia                                           7       7
# Eastern Asia                                            6       6
# Australia and New Zealand                               2       2
# North America                                           2       2
#
#                                  Health (Life Expectancy)  Freedom  \
# Region
# Sub-Saharan Africa                                     40       40
# Central and Eastern Europe                             29       29
# Latin America and Caribbean                            22       22
# Western Europe                                         21       21
# Middle East and Northern Africa                        20       20
# Southeastern Asia                                       9        9
# Southern Asia                                           7        7
# Eastern Asia                                            6        6
# Australia and New Zealand                               2        2
# North America                                           2        2
#
#                                  Trust (Government Corruption)  Generosity  \
# Region
# Sub-Saharan Africa                                          40          40
# Central and Eastern Europe                                  29          29
# Latin America and Caribbean                                 22          22
# Western Europe                                              21          21
# Middle East and Northern Africa                             20          20
# Southeastern Asia                                            9           9
# Southern Asia                                                7           7
# Eastern Asia                                                 6           6
# Australia and New Zealand                                    2           2
# North America                                                2           2
#
#                                  Dystopia Residual  year
# Region
# Sub-Saharan Africa                              40    40
# Central and Eastern Europe                      29    29
# Latin America and Caribbean                     22    22
# Western Europe                                  21    21
# Middle East and Northern Africa                 20    20
# Southeastern Asia                                9     9
# Southern Asia                                    7     7
# Eastern Asia                                     6     6
# Australia and New Zealand                        2     2
# North America                                    2     2

# %%
print("The most generous region is: Sub-Saharan Africa" )
# Out:
# The most generous region is: Sub-Saharan Africa

# %% [markdown]
# TASK 12

# %% [markdown]
# A very common test in the Hypothesis Testing (or p-value statistics) framwork is the Kolmogorov-Smornoff test (most commonly referred to as K-S test). Like the Z test we reviewed in class, its just a way to compare or two samples (or a sample and a population, but we are using the two-sample version of the test today) to measure if we can rule out that they are "the same", or more precisely, that they were exctracted  from the same population. In other words: **THE NULL HYPOTHESIS IS THAT THE TWO SAMPLES COME FROM THE SAME POPULATION**. I will explain on tuesday exactly how it works from a theoretical persoective (its one of the most intuitive ones because it has a graphical explanation), but I want you to figure out how to use it.
#
# The function you want to use is in the package `scipy` subpackage `stats` and its called `ks_2samp()`.
#
# Find the function and ues the ? to get the functions' doc string. With that, you can figure out how to use it (whta does it want in input?).
#
# Read also what the function returns:
#
# the _statistic_ is the value of the quantity you measured, is the same kind of quantity as the Z we calculated for the Z test in class, but for the K-S test.
#
# Scipy also conveniently returns the _p-value_: this corresponds to the probability that a result as extreme as the one you got would have been obetained by chance. If that probability is _lower_ than your threshold (which you should have set the second I told you this was a p-value kind of test!!!!! explicitly write your significance threshold before you run the test: 2sigma = 16%, 2sigma = 5%, 3sigma = 0.3%...) *you can reject the Null hypothesis that the distributions are from the same population*.
#
# So the task is to
# - Compare the Generosity distribution of values with themselves (that is, pass happiness15["Generosity"] as both arguments of the function).
# Think about why you get the result. Does the p-value make sense? explain.
#
# - Now look at your correlation results, take the two columns that have the largest correlation, and calculate the KS test for those. What can you say about them? (write it in a cell of code)

# %%
import scipy as sp
from scipy import stats

# %% [markdown]
# Here is the code:

# %%
sp.stats.ks_2samp(data1, data2)

# %% [markdown]
# Here is the ouput:

# %%
KstestResult(statistic=?, pvalue=?)

# %% [markdown]
# If pvalues is less than the defined threshold, we reject the null hypothesis in favor of the alternative.

# %% [markdown]
# Here we choose a confidence level of 95%; that is, we will reject the null hypothesis in favor of the alternative if the p-value is less than 0.05.
# Thus, threshold is 2$\sigma$=5%.

# %%
#generosity with itself
sp.stats.ks_2samp(happiness15["Generosity"], happiness15["Generosity"])
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=0.0, statistic_sign=1)

# %% [markdown]
# p_value is not less than the thereshold, so we can not reject the null HP.
# This makes sense because the null hypothesis assumes that both samples are drawn from the same population and here both samples are equal!

# %%
#the two variable that are most correlated with each other
sp.stats.ks_2samp( happiness15['Economy (GDP per Capita)'], happiness15["Happiness Score"])
# Out:
# KstestResult(statistic=1.0, pvalue=2.1009010730021812e-95, statistic_location=1.69042, statistic_sign=1)

# %% [markdown]
# The p-value is less than the threshold 0.05. So we can reject the null HP in favor of the alternative HP.
